# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"  
import pickle
import numpy as np
import pandas as pd
from deepmreye import analyse, architecture, preprocess, train
from deepmreye.util import data_generator, model_opts

subject_pool = {
                'sub-003':{'ses-07R':([1,2,3,4,5], False),
                           'ses-13R':([1,2,4,5,6], False)},
                'sub-004':{'ses-07R':([1,2,3,4,5,6], False),
                           'ses-13':([1,2,3,4,5,6], False)},
                'sub-005':{'ses-07':([1,2,3,4,5,6], True)},
                'sub-006':{'ses-07R':([1,2,3,4,5,6], False),
                           'ses-13':([1,2,3,4,5,6], False)},
                'sub-008':{'ses-07R':([2,3,4,5,6], False),
                           'ses-13':([1,2,3,4,5,6], False)},
                'sub-009':{'ses-07':([1,2,3,4,5,6], False),
                           'ses-13':([1,2,3,5,6], False)},
                'sub-010':{'ses-07':([1,2,3,4,5], False),
                           'ses-13':([1,2,3,4,5,6], False)},
                'sub-011':{'ses-07':([1,2,3,4,5,6], False),
                           'ses-13':([1,2,3,4,5,6], False)},
                'sub-012':{'ses-07':([1,2,4,5,6], False)},
                'sub-013':{'ses-07':([1,2,3,4], False)},
                'sub-014':{'ses-07':([2,3,4,5,6], False)},
                'sub-015':{'ses-07':([1,2,3,4,5,6], False),
                           'ses-13':([1,2,3,4,5,6], False)},
                'sub-016':{'ses-07':([1,2,3,4,5,6], False),
                           'ses-13':([1,2,3,4,5,6], False)},
                'sub-017':{'ses-07':([1,2,3,4,5,6], False),
                           'ses-13':([1,2,3,4,5], False)},
                'sub-018':{'ses-07':([1,2,3,4,5,6], False),
                           'ses-13':([1,2,3,4,5,6], False)},
                'sub-020':{'ses-07':([1,2,3,4,5,6], False),
                           'ses-13':([1,2,3,4,5,6], False)},
                'sub-021':{'ses-07':([1,2,4,5,6], False),
                           'ses-13':([1,2,4,5,6], False)},
                'sub-JJY':{'ses-07':([1,2,3,4,5,6], False)},
                'sub-KMY':{'ses-07':([1,2,3,4,5,6], False)},
                'sub-PJW':{'ses-07':([1,2,3,4,6], True)},
                'sub-PBJ':{'ses-07':([1,2,3,4,5], False)}
                }

with open('minecraft_testable_data_extend3.pkl', 'rb') as f:
    testable_data = pickle.load(f)
# Out:
# 2024-12-13 09:15:09.658174: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-13 09:15:09.727243: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-13 09:15:11.015288: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
calibration_points = np.array([[200-800, 166-500], [200-800, 500-500], [200-800, 833-500],
                               [600-800, 166-500], [600-800, 500-500], [600-800, 833-500],
                               [1000-800, 166-500], [1000-800, 500-500], [1000-800, 833-500],
                               [1400-800, 166-500], [1400-800, 500-500], [1400-800, 833-500]]) * (1/78.43)
calibration_points = np.tile(calibration_points, [2,1])
calibration_order = np.array([4,11,6,2,7,0,10,5,9,8,1,3]*2)

calibration_gt = calibration_points[calibration_order, :]

calibration_time = np.arange(0,24,0.1)
calibration_x = np.zeros(240)
calibration_y = np.zeros(240)
for t, time in enumerate(calibration_time):
    x = calibration_gt[int(np.floor(time)), 0]
    y = calibration_gt[int(np.floor(time)), 1]
    calibration_x[t] = x
    calibration_y[t] = y

offsets = [1, 144, 284, 494]
n_points = [24, 12, 12, 12]

subject_MSEs = {}
for key in testable_data.keys():
    subject = key[0]
    session = key[1]
    task = key[2]
    run = key[3]
    r = int(run[4])
    print(subject, session, task, run)
    if subject not in list(subject_MSEs.keys()):
        subject_MSEs[subject] = []
    
    #
    test_data = np.load(f'processed_data/{subject}_{session}_{run}_test.npz', mmap_mode='r')
    
    test_X = [test_data['data_' + str(b)] for b in range(510)]
    test_y = [test_data['label_' + str(b)] for b in range(510)]
    test_X = np.array(test_X)[..., np.newaxis]
    test_y = np.array(test_y)
    
    opts = model_opts.get_opts()
    _, model_inference = architecture.create_standard_model(test_X.shape[1::], opts)
    model_inference.load_weights(f'model_weights/pretrained_weight_datasets_1to6.h5')
    (pred_y, euc_pred) = model_inference.predict(test_X)
    pred_y = np.median(pred_y, axis=1) #Original DeepMReye evaluation funcation used np.median
    np.save(f'results/{subject}_{session}_{run}_pred_pretrained.npy', pred_y)

    train_MSE = []
    for t, time in enumerate(range(1, 25)):
        x_pred = pred_y[time,0]
        y_pred = pred_y[time,1]
        x_data = calibration_gt[t-1,0] #np.mean(calibration_x[t*10:(t+1)*10])
        y_data = calibration_gt[t-1,1] #np.mean(calibration_y[t*10:(t+1)*10])
        train_MSE.append(np.sqrt((x_pred-x_data)**2 + (y_pred-y_data)**2))
        
    t_eval = 3
    test_MSE = []
    for t, time in enumerate(range(offsets[t_eval], offsets[t_eval]+n_points[t_eval])):
        x_pred = pred_y[time,0]
        y_pred = pred_y[time,1]
        x_data = calibration_gt[t-1,0] #np.mean(calibration_x[t*10:(t+1)*10])
        y_data = calibration_gt[t-1,1] #np.mean(calibration_y[t*10:(t+1)*10])
        test_MSE.append(np.sqrt((x_pred-x_data)**2 + (y_pred-y_data)**2))
    subject_MSEs[subject].append(np.mean(test_MSE))
    print(np.mean(train_MSE), np.mean(test_MSE))
print(subject_MSEs)
# Out:
# sub-003 ses-07R task-mcHERDING run-1
# 16/16 [==============================] - 13s 659ms/step
# 6.542711301130744 6.7514865030977615
# sub-003 ses-07R task-mcHERDING run-2
# 16/16 [==============================] - 13s 683ms/step
# 6.3945495766455736 6.504351055427478
# sub-003 ses-07R task-mcHERDING run-3
# 16/16 [==============================] - 10s 532ms/step
# 6.754711999957505 6.215514692072255
# sub-003 ses-13R task-mcHERDING run-1
# 16/16 [==============================] - 11s 608ms/step
# 6.690367616464722 6.652000429527141
# sub-003 ses-13R task-mcHERDING run-2
# 16/16 [==============================] - 13s 667ms/step
# 6.20959658996077 6.3774023515599145
# sub-003 ses-13R task-mcHERDING run-4
# 16/16 [==============================] - 12s 662ms/step
# 6.630388342477311 6.603310229114933
# sub-003 ses-13R task-mcHERDING run-5
# 16/16 [==============================] - 13s 697ms/step
# 6.556318807025174 6.765079291626532
# sub-004 ses-07R task-mcHERDING run-1
# 16/16 [==============================] - 12s 632ms/step
# 7.126503592519427 6.395466940003083
# sub-004 ses-07R task-mcHERDING run-2
# 16/16 [==============================] - 10s 541ms/step
# 6.980571917841968 6.193436082871191
# sub-004 ses-07R task-mcHERDING run-4
# 16/16 [==============================] - 13s 694ms/step
# 6.6822670011945435 6.771356198692403
# sub-004 ses-13 task-mcHERDING run-1
# 16/16 [==============================] - 13s 722ms/step
# 6.651392702026719 6.613603080099246
# sub-004 ses-13 task-mcHERDING run-3
# 16/16 [==============================] - 13s 692ms/step
# 6.589480766280893 6.569282997619101
# sub-004 ses-13 task-mcHERDING run-6
# 16/16 [==============================] - 13s 705ms/step
# 6.503208327050405 7.157335225881156
# sub-005 ses-07 task-mcHERDING run-1
# 16/16 [==============================] - 10s 536ms/step
# 6.187664471363502 6.595058369725822
# sub-005 ses-07 task-mcHERDING run-3
# 16/16 [==============================] - 14s 735ms/step
# 6.381590974312864 6.385724979904761
# sub-006 ses-07R task-mcHERDING run-1
# 16/16 [==============================] - 14s 731ms/step
# 6.03899336939583 6.503703311140444
# sub-006 ses-07R task-mcHERDING run-2
# 16/16 [==============================] - 15s 739ms/step
# 6.5795417689521996 6.462142976572099
# sub-006 ses-07R task-mcHERDING run-3
# 16/16 [==============================] - 14s 731ms/step
# 6.103857961879458 6.277537372401816
# sub-006 ses-07R task-mcHERDING run-4
# 16/16 [==============================] - 10s 545ms/step
# 6.718303119555153 6.191162584035648
# sub-006 ses-07R task-mcHERDING run-5
# 16/16 [==============================] - 11s 638ms/step
# 6.01790018537645 6.245780502727272
# sub-006 ses-07R task-mcHERDING run-6
# 16/16 [==============================] - 13s 678ms/step
# 6.433189297839196 6.360849769427712
# sub-006 ses-13 task-mcHERDING run-1
# 16/16 [==============================] - 13s 663ms/step
# 6.396570267836908 6.302401960664383
# sub-006 ses-13 task-mcHERDING run-5
# 16/16 [==============================] - 13s 696ms/step
# 6.112944547939861 6.47985538222571
# sub-006 ses-13 task-mcHERDING run-6
# 16/16 [==============================] - 12s 602ms/step
# 6.849397530596853 6.275869272043066
# sub-008 ses-07R task-mcHERDING run-2
# 16/16 [==============================] - 10s 556ms/step
# 6.578198550975195 6.167893286563572
# sub-008 ses-07R task-mcHERDING run-4
# 16/16 [==============================] - 13s 676ms/step
# 6.239764939054228 6.142243661735733
# sub-008 ses-07R task-mcHERDING run-5
# 16/16 [==============================] - 13s 678ms/step
# 6.611938369573359 6.701962292106227
# sub-008 ses-07R task-mcHERDING run-6
# 16/16 [==============================] - 13s 677ms/step
# 6.854877116943224 6.18900831673837
# sub-008 ses-13 task-mcHERDING run-3
# 16/16 [==============================] - 13s 666ms/step
# 6.27459147942318 6.365137333278113
# sub-008 ses-13 task-mcHERDING run-4
# 16/16 [==============================] - 10s 529ms/step
# 6.266151291726646 6.3365958245863725
# sub-008 ses-13 task-mcHERDING run-5
# 16/16 [==============================] - 12s 695ms/step
# 5.966074598129548 6.475770081741197
# sub-009 ses-07 task-mcHERDING run-5
# 16/16 [==============================] - 13s 686ms/step
# 6.618090356691657 6.735103822336513
# sub-010 ses-07 task-mcHERDING run-1
# 16/16 [==============================] - 13s 701ms/step
# 6.135713229942428 6.348404427141834
# sub-010 ses-07 task-mcHERDING run-2
# 16/16 [==============================] - 13s 675ms/step
# 6.258007017512824 6.172471081193096
# sub-010 ses-07 task-mcHERDING run-4
# 16/16 [==============================] - 11s 558ms/step
# 6.349432728550518 6.013127971749348
# sub-010 ses-13 task-mcHERDING run-6
# 16/16 [==============================] - 10s 567ms/step
# 6.455348953905247 6.577788943775141
# sub-011 ses-07 task-mcHERDING run-4
# 16/16 [==============================] - 13s 701ms/step
# 6.402574201384598 6.538248496938041
# sub-011 ses-13 task-mcHERDING run-2
# 16/16 [==============================] - 13s 700ms/step
# 6.4316221610405035 6.733533722411495
# sub-011 ses-13 task-mcHERDING run-3
# 16/16 [==============================] - 12s 650ms/step
# 6.096496800185328 7.42656752775632
# sub-011 ses-13 task-mcHERDING run-4
# 16/16 [==============================] - 13s 641ms/step
# 6.377075770374051 6.509436489151777
# sub-011 ses-13 task-mcHERDING run-5
# 16/16 [==============================] - 10s 535ms/step
# 6.241518477011216 6.513097333773253
# sub-011 ses-13 task-mcHERDING run-6
# 16/16 [==============================] - 13s 675ms/step
# 6.580978239125855 6.864940998006458
# sub-012 ses-07 task-mcHERDING run-4
# 16/16 [==============================] - 13s 679ms/step
# 6.245911950919378 6.250192857341719
# sub-013 ses-07 task-mcHERDING run-1
# 16/16 [==============================] - 13s 714ms/step
# 7.171641072918249 6.688983510560168
# sub-013 ses-07 task-mcHERDING run-2
# 16/16 [==============================] - 13s 679ms/step
# 6.6587064392848 6.961181727680145
# sub-013 ses-07 task-mcHERDING run-4
# 16/16 [==============================] - 10s 526ms/step
# 7.205069548916541 6.902901718709525
# sub-014 ses-07 task-mcHERDING run-2
# 16/16 [==============================] - 11s 645ms/step
# 7.186628691147475 6.288763976058466
# sub-014 ses-07 task-mcHERDING run-4
# 16/16 [==============================] - 14s 692ms/step
# 6.3906428496177625 6.580450068089277
# sub-014 ses-07 task-mcHERDING run-5
# 16/16 [==============================] - 13s 644ms/step
# 6.7523645452298595 6.250038944189746
# sub-015 ses-07 task-mcHERDING run-1
# 16/16 [==============================] - 13s 690ms/step
# 6.43173099573184 7.227043370661718
# sub-015 ses-07 task-mcHERDING run-3
# 16/16 [==============================] - 11s 574ms/step
# 6.648062311394338 6.24347816446976
# sub-015 ses-07 task-mcHERDING run-4
# 16/16 [==============================] - 11s 573ms/step
# 6.7194702779003395 6.3729888260176315
# sub-015 ses-07 task-mcHERDING run-5
# 16/16 [==============================] - 13s 695ms/step
# 6.8254072716686665 6.5125519610055465
# sub-015 ses-13 task-mcHERDING run-1
# 16/16 [==============================] - 13s 661ms/step
# 6.327072955473675 7.078644725707886
# sub-015 ses-13 task-mcHERDING run-2
# 16/16 [==============================] - 13s 693ms/step
# 6.44257500181278 6.900425201925728
# sub-015 ses-13 task-mcHERDING run-5
# 16/16 [==============================] - 12s 614ms/step
# 6.492467660101944 6.73607435619335
# sub-015 ses-13 task-mcHERDING run-6
# 16/16 [==============================] - 10s 532ms/step
# 6.748524294489222 6.951767919613965
# sub-016 ses-07 task-mcHERDING run-1
# 16/16 [==============================] - 14s 724ms/step
# 6.784511238335284 7.040063376994837
# sub-016 ses-07 task-mcHERDING run-2
# 16/16 [==============================] - 14s 727ms/step
# 6.421702896975298 6.739314957350959
# sub-016 ses-07 task-mcHERDING run-3
# 16/16 [==============================] - 14s 729ms/step
# 7.368628932001019 6.8073887783040234
# sub-016 ses-07 task-mcHERDING run-4
# 16/16 [==============================] - 14s 733ms/step
# 6.363198952123422 6.334991821729671
# sub-016 ses-07 task-mcHERDING run-5
# 16/16 [==============================] - 10s 531ms/step
# 6.770566564001907 6.173347581655545
# sub-016 ses-07 task-mcHERDING run-6
# 16/16 [==============================] - 13s 695ms/step
# 6.829846046315886 7.210058454127363
# sub-016 ses-13 task-mcHERDING run-1
# 16/16 [==============================] - 13s 696ms/step
# 6.493501446208729 6.310710465559879
# sub-016 ses-13 task-mcHERDING run-2
# 16/16 [==============================] - 13s 692ms/step
# 6.666216817786238 6.768918147882274
# sub-016 ses-13 task-mcHERDING run-3
# 16/16 [==============================] - 13s 683ms/step
# 6.856113821728254 7.533172614126596
# sub-016 ses-13 task-mcHERDING run-4
# 16/16 [==============================] - 10s 558ms/step
# 6.590226428002986 6.816796311459647
# sub-016 ses-13 task-mcHERDING run-5
# 16/16 [==============================] - 12s 639ms/step
# 6.705106661703186 6.6412142765593964
# sub-016 ses-13 task-mcHERDING run-6
# 16/16 [==============================] - 13s 682ms/step
# 6.823260936865658 6.651111221932754
# sub-018 ses-07 task-mcHERDING run-2
# 16/16 [==============================] - 13s 671ms/step
# 6.811556842511439 6.846685702227021
# sub-018 ses-07 task-mcHERDING run-3
# 16/16 [==============================] - 13s 655ms/step
# 6.865214290402252 7.120760652065201
# sub-018 ses-07 task-mcHERDING run-4
# 16/16 [==============================] - 11s 556ms/step
# 6.8362075997812655 6.641810720813919
# sub-018 ses-07 task-mcHERDING run-5
# 16/16 [==============================] - 11s 541ms/step
# 6.396875599326105 6.7162083611848615
# sub-018 ses-07 task-mcHERDING run-6
# 16/16 [==============================] - 13s 682ms/step
# 7.063854142498726 7.153922717244778
# sub-018 ses-13 task-mcHERDING run-1
# 16/16 [==============================] - 13s 686ms/step
# 7.124497851524342 7.0387143886894465
# sub-018 ses-13 task-mcHERDING run-2
# 16/16 [==============================] - 13s 679ms/step
# 6.758816930992789 6.612143253191128
# sub-018 ses-13 task-mcHERDING run-4
# 16/16 [==============================] - 13s 659ms/step
# 6.529287329094416 7.127076982340367
# sub-018 ses-13 task-mcHERDING run-5
# 16/16 [==============================] - 10s 528ms/step
# 6.7980699212085725 6.889566347962854
# sub-018 ses-13 task-mcHERDING run-6
# 16/16 [==============================] - 13s 680ms/step
# 6.575322310373146 6.634854024646885
# sub-020 ses-07 task-mcHERDING run-1
# 16/16 [==============================] - 13s 684ms/step
# 6.550024911296748 6.058267628859801
# sub-020 ses-07 task-mcHERDING run-2
# 16/16 [==============================] - 13s 673ms/step
# 7.169227259718467 6.012905876220217
# sub-020 ses-07 task-mcHERDING run-4
# 16/16 [==============================] - 13s 681ms/step
# 7.002372479776497 6.389666556761925
# sub-020 ses-07 task-mcHERDING run-5
# 16/16 [==============================] - 10s 540ms/step
# 7.327437330870434 6.450563476008768
# sub-020 ses-13 task-mcHERDING run-3
# 16/16 [==============================] - 12s 645ms/step
# 6.781806813469442 6.8563285057704135
# sub-020 ses-13 task-mcHERDING run-4
# 16/16 [==============================] - 13s 669ms/step
# 6.3193228589113914 6.856346821679129
# sub-020 ses-13 task-mcHERDING run-5
# 16/16 [==============================] - 12s 633ms/step
# 6.776567573678096 6.470557676205879
# sub-020 ses-13 task-mcHERDING run-6
# 16/16 [==============================] - 12s 656ms/step
# 6.195853157135137 6.779953464386581
# sub-021 ses-07 task-mcHERDING run-1
# 16/16 [==============================] - 11s 584ms/step
# 6.5625944409782235 6.951528710412307
# sub-021 ses-07 task-mcHERDING run-2
# 16/16 [==============================] - 11s 565ms/step
# 6.756543913275627 6.788060033734783
# sub-021 ses-07 task-mcHERDING run-6
# 16/16 [==============================] - 12s 651ms/step
# 6.153460163923543 6.441654205453356
# sub-021 ses-13 task-mcHERDING run-4
# 16/16 [==============================] - 12s 647ms/step
# 6.487198415173993 6.707591821209188
# sub-JJY ses-07 task-mcHERDING run-1
# 16/16 [==============================] - 12s 634ms/step
# 7.278362290013152 6.508988652034351
# sub-JJY ses-07 task-mcHERDING run-2
# 16/16 [==============================] - 12s 638ms/step
# 6.356158167766673 7.500899750855566
# sub-JJY ses-07 task-mcHERDING run-3
# 16/16 [==============================] - 10s 530ms/step
# 6.349302639445298 6.692465884446439
# sub-JJY ses-07 task-mcHERDING run-4
# 16/16 [==============================] - 14s 735ms/step
# 6.322323736922711 5.6662461248681675
# sub-JJY ses-07 task-mcHERDING run-5
# 16/16 [==============================] - 15s 783ms/step
# 6.29722073962166 7.016055585229495
# sub-JJY ses-07 task-mcHERDING run-6
# 16/16 [==============================] - 14s 737ms/step
# 6.49514488273928 6.836926249324757
# sub-KMY ses-07 task-mcHERDING run-2
# 16/16 [==============================] - 12s 641ms/step
# 6.362197763442912 6.501921567195752
# sub-KMY ses-07 task-mcHERDING run-3
# 16/16 [==============================] - 10s 533ms/step
# 6.6875561587908585 6.799006691862772
# sub-KMY ses-07 task-mcHERDING run-4
# 16/16 [==============================] - 14s 724ms/step
# 6.834298752437005 6.720915638264447
# sub-KMY ses-07 task-mcHERDING run-5
# 16/16 [==============================] - 14s 718ms/step
# 6.569920856539466 6.734889016341731
# sub-KMY ses-07 task-mcHERDING run-6
# 16/16 [==============================] - 14s 729ms/step
# 6.505310328215291 6.619149612512062
# sub-PJW ses-07 task-mcHERDING run-2
# 16/16 [==============================] - 14s 722ms/step
# 6.49202955369487 6.2671111521798215
# sub-PJW ses-07 task-mcHERDING run-3
# 16/16 [==============================] - 10s 540ms/step
# 6.285623047788408 6.134980963890972
# sub-PJW ses-07 task-mcHERDING run-4
# 16/16 [==============================] - 13s 679ms/step
# 6.401649890883519 6.276667226974978
# sub-PJW ses-07 task-mcHERDING run-6
# 16/16 [==============================] - 15s 764ms/step
# 6.325892505789743 6.255262579505042
# sub-PBJ ses-07 task-mcHERDING run-1
# 16/16 [==============================] - 14s 735ms/step
# 6.742949676253179 6.712589953839822
# sub-PBJ ses-07 task-mcHERDING run-2
# 16/16 [==============================] - 14s 717ms/step
# 6.367727136154662 6.456793672609417
# sub-PBJ ses-07 task-mcHERDING run-3
# 16/16 [==============================] - 11s 566ms/step
# 6.811844093473174 6.033830979741828
# sub-PBJ ses-07 task-mcHERDING run-4
# 16/16 [==============================] - 11s 574ms/step
# 6.247667436207723 6.679943162709596
# sub-PBJ ses-07 task-mcHERDING run-5
# 16/16 [==============================] - 13s 690ms/step
# 6.712814307551533 6.564548491508337
# {'sub-003': [6.7514865030977615, 6.504351055427478, 6.215514692072255, 6.652000429527141, 6.3774023515599145, 6.603310229114933, 6.765079291626532], 'sub-004': [6.395466940003083, 6.193436082871191, 6.771356198692403, 6.613603080099246, 6.569282997619101, 7.157335225881156], 'sub-005': [6.595058369725822, 6.385724979904761], 'sub-006': [6.503703311140444, 6.462142976572099, 6.277537372401816, 6.191162584035648, 6.245780502727272, 6.360849769427712, 6.302401960664383, 6.47985538222571, 6.275869272043066], 'sub-008': [6.167893286563572, 6.142243661735733, 6.701962292106227, 6.18900831673837, 6.365137333278113, 6.3365958245863725, 6.475770081741197], 'sub-009': [6.735103822336513], 'sub-010': [6.348404427141834, 6.172471081193096, 6.013127971749348, 6.577788943775141], 'sub-011': [6.538248496938041, 6.733533722411495, 7.42656752775632, 6.509436489151777, 6.513097333773253, 6.864940998006458], 'sub-012': [6.250192857341719], 'sub-013': [6.688983510560168, 6.961181727680145, 6.902901718709525], 'sub-014': [6.288763976058466, 6.580450068089277, 6.250038944189746], 'sub-015': [7.227043370661718, 6.24347816446976, 6.3729888260176315, 6.5125519610055465, 7.078644725707886, 6.900425201925728, 6.73607435619335, 6.951767919613965], 'sub-016': [7.040063376994837, 6.739314957350959, 6.8073887783040234, 6.334991821729671, 6.173347581655545, 7.210058454127363, 6.310710465559879, 6.768918147882274, 7.533172614126596, 6.816796311459647, 6.6412142765593964, 6.651111221932754], 'sub-018': [6.846685702227021, 7.120760652065201, 6.641810720813919, 6.7162083611848615, 7.153922717244778, 7.0387143886894465, 6.612143253191128, 7.127076982340367, 6.889566347962854, 6.634854024646885], 'sub-020': [6.058267628859801, 6.012905876220217, 6.389666556761925, 6.450563476008768, 6.8563285057704135, 6.856346821679129, 6.470557676205879, 6.779953464386581], 'sub-021': [6.951528710412307, 6.788060033734783, 6.441654205453356, 6.707591821209188], 'sub-JJY': [6.508988652034351, 7.500899750855566, 6.692465884446439, 5.6662461248681675, 7.016055585229495, 6.836926249324757], 'sub-KMY': [6.501921567195752, 6.799006691862772, 6.720915638264447, 6.734889016341731, 6.619149612512062], 'sub-PJW': [6.2671111521798215, 6.134980963890972, 6.276667226974978, 6.255262579505042], 'sub-PBJ': [6.712589953839822, 6.456793672609417, 6.033830979741828, 6.679943162709596, 6.564548491508337]}

# %%
import matplotlib.pyplot as plt

time_sta = 494
time_end = time_sta + 12

fig, axes = plt.subplots(2,1,figsize=(3,3), dpi=300, sharex=True, sharey=True)
axes[0].plot(calibration_time[:120]+time_sta, calibration_x[:120], c='#333333')
axes[0].plot(np.arange(time_sta, time_end)+0.5, pred_y[time_sta:time_end,0], c='#ff0064')
axes[1].plot(calibration_time[:120]+time_sta, calibration_y[:120], c='#333333')
axes[1].plot(np.arange(time_sta, time_end)+0.5, pred_y[time_sta:time_end,1], c='#ff0064')
axes[0].set_ylim(-11,11)
# Out:
# (-11.0, 11.0)

# %%
subject_pred = {}
for key in testable_data.keys():
    subject, session, task, run = key
    if subject not in subject_pred:
        subject_pred[subject] = []
    pred_y = np.load(f'results/{subject}_{session}_{run}_pred_pretrained.npy')
    subject_pred[subject].append(pred_y)

for subject in subject_pred.keys():
    subject_pred[subject] = np.mean(subject_pred[subject], axis=0)

# draw the group-averaged pred_y with standard error band across subjects
time_sta = 494
time_end = time_sta + 12
from scipy.stats import sem
group_pred_y = np.mean([subject_pred[subject] for subject in subject_pred], axis=0)
group_pred_y_se = sem([subject_pred[subject] for subject in subject_pred], axis=0)

# Plot with error bars
fig, axes = plt.subplots(2, 1, figsize=(3, 3), dpi=300, sharex=True, sharey=True)
axes[0].plot(calibration_time[:120] + time_sta, calibration_x[:120], c='#333333')
axes[0].errorbar(np.arange(time_sta, time_end) + 0.5, 10*group_pred_y[time_sta:time_end, 0], 
                 yerr=10*group_pred_y_se[time_sta:time_end, 0], fmt='-', c='#ff0064')
axes[1].plot(calibration_time[:120] + time_sta, calibration_y[:120], c='#333333')
axes[1].errorbar(np.arange(time_sta, time_end) + 0.5, 10*group_pred_y[time_sta:time_end, 1], 
                 yerr=10*group_pred_y_se[time_sta:time_end, 1], fmt='-', c='#ff0064')
axes[0].set_ylim(-11, 11)
# Out:
# (-11.0, 11.0)

# %%
subject_pred = {}
for key in testable_data.keys():
    subject, session, task, run = key
    if subject not in subject_pred:
        subject_pred[subject] = []
    pred_y = np.load(f'results/{subject}_{session}_{run}_pred_pretrained.npy')
    subject_pred[subject].append(pred_y)

window_size = 10
deviation = {subject: [] for subject in subject_pred}
for subject in subject_pred:
    for run_pred in subject_pred[subject]:
        run_deviation = np.zeros(510)
        for t in range(len(run_pred)):
            run_deviation[t] = np.sqrt(run_pred[t, 0]**2 + run_pred[t,1]**2)
        deviation[subject].append(run_deviation)
    deviation[subject] = np.mean(deviation[subject], axis=0)

# Calculate group-averaged local variance and standard error
group_deviation_x = np.mean([deviation[subject] for subject in subject_pred], axis=0)
group_deviation_sem = sem([deviation[subject] for subject in subject_pred], axis=0)

# Plot group-averaged local variance with error bands
time_points = np.arange(510)

fig, ax = plt.subplots(1, 1, figsize=(4, 3), dpi=300, sharex=True)
ax.plot(time_points, group_deviation_x, c='#ff0064', lw=0.5)
ax.fill_between(time_points, group_deviation_x - group_deviation_sem, 
                     group_deviation_x + group_deviation_sem, color='#ff0064', alpha=0.3)
ax.set_title('Group-averaged Local Variance (X)')
ax.set_ylabel('Variance')

plt.tight_layout()
plt.show()
